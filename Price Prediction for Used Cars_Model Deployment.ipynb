# %% [markdown]
# # Model Deployment
# In this .ipynb file, a simple demonstration for model deployment is shown. As illustrated below, it shows how the predictions for prices can be easily made from a csv file using the Price_Prediction_for_Used_Cars_Module.py developed earlier on.

# %% [markdown]
# Firstly, we will import everything (*) from Price_Prediction_for_Used_Cars_Module:

# %%
from Price_Prediction_for_Used_Cars_Module import *

# %% [markdown]
# Next, we will import the csv file which will be used for the price predictions:

# %%
df_for_deployment = pd.read_csv("Cars_For Deployment.csv")
df_for_deployment
# Out:
#            Brand         Model       Body  Mileage  EngineV Engine Type  \
# 0            BMW           320      sedan      277      2.0      Petrol
# 1  Mercedes-Benz  Sprinter 212        van      427      2.9      Diesel
# 2  Mercedes-Benz         S 500      sedan      358      5.0         Gas
# 3           Audi            Q7  crossover      240      4.2      Petrol
# 4         Toyota         Rav 4  crossover      120      2.0      Petrol
# 5  Mercedes-Benz        GLS 63  crossover        0      5.5      Petrol
# 6            BMW           320      sedan      438      2.0         Gas
# 7           Audi            A6      vagon      200      2.7      Diesel
# 8        Renault        Megane      vagon      193      1.5      Diesel
# 9     Volkswagen       Golf IV      other      212      1.8         Gas
#
#   Registration  Year
# 0          yes  1991
# 1          yes  1999
# 2          yes  2003
# 3          yes  2007
# 4          yes  2011
# 5          yes  2016
# ...

# %% [markdown]
# Next, we can just use the My_Cars_Model() function from the Price_Prediction_for_Used_Cars_Module for price predictions:

# %%
My_Cars_Model(df_for_deployment)
# Out:
#            Brand         Model       Body  Mileage  EngineV Engine Type  \
# 0            BMW           320      sedan      277      2.0      Petrol
# 1  Mercedes-Benz  Sprinter 212        van      427      2.9      Diesel
# 2  Mercedes-Benz         S 500      sedan      358      5.0         Gas
# 3           Audi            Q7  crossover      240      4.2      Petrol
# 4         Toyota         Rav 4  crossover      120      2.0      Petrol
# 5  Mercedes-Benz        GLS 63  crossover        0      5.5      Petrol
# 6            BMW           320      sedan      438      2.0         Gas
# 7           Audi            A6      vagon      200      2.7      Diesel
# 8        Renault        Megane      vagon      193      1.5      Diesel
# 9     Volkswagen       Golf IV      other      212      1.8         Gas
#
#   Registration  Year  Predicted Price
# 0          yes  1991           3296.2
# 1          yes  1999           7377.2
# 2          yes  2003          18030.8
# ...

# %% [markdown]
# As shown above, the predicted price for the second hand cars are shown in the last column. This demonstrates how to easily make price predictions from a csv file just by using a few very basic lines of codes, while leaving all the data preprocessing, manipulation etc. behind the scene.
